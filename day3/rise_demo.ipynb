# %% [markdown]
# # RISE is goood !

# %% [markdown]
# Un "-"

# %% [markdown]
# Un fragment

# %% [markdown]
# Un subslide

# %% [markdown]
# # Un nouveau slide

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import YouTubeVideo
# %matplotlib nbagg

# %%
def plot(fig, ax):
    ax.plot(np.random.rand(10), marker = "o")
    plt.grid()
    plt.xlabel("Tutu")
    plt.ylabel("Tata")
    plt.title("Le graphe qui tue !")

# %%
plot(*plt.subplots())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Une vraiment grosse fusée
#
# Falcon
# **heavy**
# `code`
# *italique*

# %%
YouTubeVideo("bCc16uozHVE")

# %% [markdown]
# ![raton](./raton.jpg)

# %%
import pandas as pd
data = pd.DataFrame(np.random.rand(5,5))
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-4589c8f12b0b> in <module>()
# ----> 1 import pandas as pd
#       2 data = pd.DataFrame(np.random.rand(5,5))
#       3 data
#
# ModuleNotFoundError: No module named 'pandas'
