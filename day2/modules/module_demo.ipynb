# %% [markdown]
# # Create a module with Python

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import myModule18 as mm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
x = np.linspace(0., 10., 100)
plt.figure()
plt.plot(x, mm.tools.myFunc(x))
plt.grid()
plt.xlabel("Speed, $\\theta$ [m/s]")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="525.2499843463306">

# %%
plt.plot(np.random.rand(10))

# %%
"{0:.2f} + {1}".format(3,"tomate")
# Out:
# '3.00 + tomate'

# %%
x = np.linspace(0., 10., 200)
plt.figure()
colors = "rbcm"
line_styles = ["-", "--", "-."]
f = [1., 2., 5., 7, 8, 10]
for i in range(len(f)):
    c = colors[i % len(colors)]
    ls = line_styles[i % len(line_styles)]
    plt.plot(x, np.sin(2. * np.pi * f[i]/50 * x),
             color = c,
             linestyle = ls,
             label = "$f = {0}$".format(f[i]))
plt.grid()
plt.legend(loc =  "best")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333142648146">
